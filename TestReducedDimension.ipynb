# %%
# Read pre_normalized data

import pandas as pd
import os

# Read data
pre_normalized_path = os.path.join('data', 'csvs', "pre_normalized.csv")

df = pd.read_csv(pre_normalized_path)

# %%
# Create CountVectorizer using filtered vocab
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer


# load filtered vocab from csv
filtered_vocab_path = os.path.join('data', 'csvs', "filtered_vocab.csv")

# read as a dictionary with key as word and value as index
filtered_vocab = pd.read_csv(filtered_vocab_path).set_index('word').to_dict()['index']

vectorizer = TfidfVectorizer(vocabulary=filtered_vocab, strip_accents="ascii", lowercase=True)

# %%
# Fit and transform the vectorizer on the text data
X = vectorizer.fit_transform(df['text']).toarray()
y = df['label']

# %%
# Train a LGBMClassifier on the count vectorized data
from lightgbm import LGBMClassifier

# Create a LGBMClassifier
lgbm = LGBMClassifier()

# Fit the classifier to the data
lgbm.fit(X, y)
# Out:
# LGBMClassifier()

# %%
from sklearn.metrics import accuracy_score

# Read the custom data
custom_data_path = os.path.join('data', 'csvs', "news_validation.csv")
custom_df = pd.read_csv(custom_data_path)

# Try to predict the label of the custom data
custom_X = vectorizer.transform(custom_df['text']).toarray()
custom_y = custom_df['label']

# Predict the labels of the custom data
custom_y_pred = lgbm.predict(custom_X)
print(accuracy_score(custom_y, custom_y_pred))
# Out:
# 0.8571428571428571

# %%
# read the covid data
covid_data_path = os.path.join('data', 'csvs', "covid.csv")
covid_df = pd.read_csv(covid_data_path)

# Try to predict the label of the custom data
covid_X = vectorizer.transform(covid_df['text']).toarray()
covid_y = covid_df['label']

# Predict the labels of the custom data
covid_y_pred = lgbm.predict(covid_X)
print(accuracy_score(covid_y, covid_y_pred))
# Out:
# 0.6666666666666666

# %%
# Fit a MLPClassifier on the count vectorized data
from sklearn.neural_network import MLPClassifier

# Create a MLPClassifier
mlp = MLPClassifier(max_iter=1000)

# Fit the classifier to the data
mlp.fit(X, y)

# Predict the labels of the custom data
custom_y_pred = mlp.predict(custom_X)
print(accuracy_score(custom_y, custom_y_pred))

# Predict the labels of the covid data
covid_y_pred = mlp.predict(covid_X)
print(accuracy_score(covid_y, covid_y_pred))
# Out:
# 0.8571428571428571
# 0.7

# %%
# Send HTTP request to the API endpoint https://nilc-fakenews.herokuapp.com/ajax/check_web/ with the field text set to the text of the article and the field model set to 'unigramas' use the cookie xr3HZGxMUGv5GL8CZ2e2ZhOZXew7iaHPzgdeEhmVDupCyHeh5gD6EaHyrhy2A6aZ with origin https://nilc-fakenews.herokuapp.com/

import requests

def pad_article(article):
    original_article = article
    while len(article.split()) < 100:
        article += "\n\n" + original_article
    
    return article

# for each article in the custom_X dataset send a request to the API endpoint
# and check if the result is the same as the one obtained with the model
convert_label = {'REAL': 'true', 'FAKE': 'fake'}

# Shuffle the data
#fake_check_df = df.sample(frac=1).head(100)
fake_check_df = covid_df

models = ['unigramas', 'pos']
models_name = ['Palavras do texto', 'Classes gramaticais']
fake_check_predictions_df = pd.DataFrame(columns=['text', 'label', 'model', 'prediction'])

# for each file in the data/text_files/covid_dataset folder
for model, model_name in zip(models, models_name):
    for folder in ['fake', 'true']:
        for file in os.listdir('data/text_files/covid_dataset/' + folder):
            with open('data/text_files/covid_dataset/' + folder + '/' + file, 'r', encoding='utf-8') as f:
                article = pad_article(f.read())
                label = folder
                response = requests.post('http://nilc-fakenews.herokuapp.com/ajax/check_web/', 
                                        data={'text': article, 'model': model}, 
                                        cookies={'csrftoken': 'xr3HZGxMUGv5GL8CZ2e2ZhOZXew7iaHPzgdeEhmVDupCyHeh5gD6EaHyrhy2A6aZ'}, 
                                        headers={
                                            'Origin': 'https://nilc-fakenews.herokuapp.com/',
                                            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/111.0',
                                            'Referer': 'https://nilc-fakenews.herokuapp.com/',
                                            'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                                            'Host': 'nilc-fakenews.herokuapp.com',
                                            'X-CSRFToken': 'xr3HZGxMUGv5GL8CZ2e2ZhOZXew7iaHPzgdeEhmVDupCyHeh5gD6EaHyrhy2A6aZ',
                                            'X-Requested-With': 'XMLHttpRequest'})

                pred = convert_label[response.json()['result']]
                new_row = pd.DataFrame([[article, label, model_name, pred]], columns=['text', 'label', 'model', 'prediction'], index=[0])
                fake_check_predictions_df = pd.concat([fake_check_predictions_df, new_row], ignore_index=True)

# %%
fake_check_predictions_df
# Out:
#                                                  text label  \
# 0   Olá eu sou médico sanitarista e a minha especi...  fake
# 1   Isso aí, galera do bem. Já no hospital aqui, s...  fake
# 2   ESLOVÊNIA ESCANDALIZADA - Ontem estourou um gr...  fake
# 3   Presidente da OMS não recomenda Carnaval em 20...  fake
# 4   Uma comparação de relatórios oficiais do gover...  fake
# 5   Bolsas de sangue de não vacinado versus sangue...  fake
# 6   os testes PCR de Covid-19 são estudos da Unive...  fake
# 7   Diretor geral da OMS Tedros Adhanom diz que nã...  fake
# 8   Tedros Adhanom Ghebreyesus, o atual diretor da...  fake
# 9   Oi, pessoal. Bom dia. Meu nome é Mônica Travas...  fake
# 10  Porque a proteína spike sintética não perdoa. ...  fake
# 11  Atenção. Limão testa positivo para Covid! Essa...  fake
# 12  Existe agora uma resolução isentando os deputa...  fake
# 13  Não se engane, as reações adversas não são rar...  fake
# 14  Advertência no metrô de Paris sobre AVC em cri...  fake
# 15  Material genético coletado no mercado chinês p...  true
# 16  A expectativa de vida nos Estados Unidos caiu ...  true
# 17  A Procuradoria-Geral da República afirmou ao S...  true
# 18  Estudo feito pelo Instituto Todos Pela Saúde (...  true
# 19  Quase 37 milhões de pessoas na China podem ter...  true
# 20  O ministro Alexandre de Moraes, do Supremo Tri...  true
# 21  Problemas neurológicos estão entre as complica...  true
# 22  Um relatório de inteligência do Departamento d...  true
# 23  A Agência Nacional de Vigilância Sanitária (An...  true
# 24  O presidente Lula e a ministra da Saúde, Nísia...  true
# 25  A política chinesa de "Covid zero" foi alvo de...  true
# 26  Enquanto cidades brasileiras enfrentam a falta...  true
# 27  Um estudo da Unicamp que analisou 3.318 vídeos...  true
# 28  O parque temático Disneyland fechou suas porta...  true
# 29  Os testes iniciais de fase 1 da vacina intrana...  true
# 30  Olá eu sou médico sanitarista e a minha especi...  fake
# 31  Isso aí, galera do bem. Já no hospital aqui, s...  fake
# 32  ESLOVÊNIA ESCANDALIZADA - Ontem estourou um gr...  fake
# 33  Presidente da OMS não recomenda Carnaval em 20...  fake
# 34  Uma comparação de relatórios oficiais do gover...  fake
# 35  Bolsas de sangue de não vacinado versus sangue...  fake
# 36  os testes PCR de Covid-19 são estudos da Unive...  fake
# 37  Diretor geral da OMS Tedros Adhanom diz que nã...  fake
# 38  Tedros Adhanom Ghebreyesus, o atual diretor da...  fake
# 39  Oi, pessoal. Bom dia. Meu nome é Mônica Travas...  fake
# 40  Porque a proteína spike sintética não perdoa. ...  fake
# 41  Atenção. Limão testa positivo para Covid! Essa...  fake
# 42  Existe agora uma resolução isentando os deputa...  fake
# 43  Não se engane, as reações adversas não são rar...  fake
# 44  Advertência no metrô de Paris sobre AVC em cri...  fake
# 45  Material genético coletado no mercado chinês p...  true
# 46  A expectativa de vida nos Estados Unidos caiu ...  true
# 47  A Procuradoria-Geral da República afirmou ao S...  true
# 48  Estudo feito pelo Instituto Todos Pela Saúde (...  true
# 49  Quase 37 milhões de pessoas na China podem ter...  true
# 50  O ministro Alexandre de Moraes, do Supremo Tri...  true
# 51  Problemas neurológicos estão entre as complica...  true
# 52  Um relatório de inteligência do Departamento d...  true
# 53  A Agência Nacional de Vigilância Sanitária (An...  true
# 54  O presidente Lula e a ministra da Saúde, Nísia...  true
# 55  A política chinesa de "Covid zero" foi alvo de...  true
# 56  Enquanto cidades brasileiras enfrentam a falta...  true
# 57  Um estudo da Unicamp que analisou 3.318 vídeos...  true
# 58  O parque temático Disneyland fechou suas porta...  true
# 59  Os testes iniciais de fase 1 da vacina intrana...  true
#
#                   model prediction
# 0     Palavras do texto       fake
# 1     Palavras do texto       true
# 2     Palavras do texto       true
# 3     Palavras do texto       true
# 4     Palavras do texto       fake
# 5     Palavras do texto       fake
# 6     Palavras do texto       true
# 7     Palavras do texto       true
# 8     Palavras do texto       fake
# 9     Palavras do texto       fake
# 10    Palavras do texto       fake
# 11    Palavras do texto       fake
# 12    Palavras do texto       fake
# 13    Palavras do texto       fake
# 14    Palavras do texto       fake
# 15    Palavras do texto       true
# 16    Palavras do texto       true
# 17    Palavras do texto       true
# 18    Palavras do texto       true
# 19    Palavras do texto       true
# 20    Palavras do texto       true
# 21    Palavras do texto       fake
# 22    Palavras do texto       true
# 23    Palavras do texto       true
# 24    Palavras do texto       true
# 25    Palavras do texto       fake
# 26    Palavras do texto       true
# 27    Palavras do texto       true
# 28    Palavras do texto       true
# 29    Palavras do texto       true
# 30  Classes gramaticais       fake
# 31  Classes gramaticais       true
# 32  Classes gramaticais       true
# 33  Classes gramaticais       true
# 34  Classes gramaticais       fake
# 35  Classes gramaticais       true
# 36  Classes gramaticais       true
# 37  Classes gramaticais       fake
# 38  Classes gramaticais       true
# 39  Classes gramaticais       fake
# 40  Classes gramaticais       fake
# 41  Classes gramaticais       fake
# 42  Classes gramaticais       fake
# 43  Classes gramaticais       fake
# 44  Classes gramaticais       true
# 45  Classes gramaticais       true
# 46  Classes gramaticais       true
# 47  Classes gramaticais       true
# 48  Classes gramaticais       true
# 49  Classes gramaticais       fake
# 50  Classes gramaticais       true
# 51  Classes gramaticais       true
# 52  Classes gramaticais       true
# 53  Classes gramaticais       true
# 54  Classes gramaticais       fake
# 55  Classes gramaticais       true
# 56  Classes gramaticais       true
# 57  Classes gramaticais       true
# 58  Classes gramaticais       fake
# 59  Classes gramaticais       fake

# %%
for model in models_name:
    print(f'[{model}] Accuracy of the model: ', accuracy_score(fake_check_predictions_df[fake_check_predictions_df['model'] == model]['label'], fake_check_predictions_df[fake_check_predictions_df['model'] == model]['prediction']))
# Out:
# [Palavras do texto] Accuracy of the model:  0.7666666666666667
# [Classes gramaticais] Accuracy of the model:  0.6333333333333333
