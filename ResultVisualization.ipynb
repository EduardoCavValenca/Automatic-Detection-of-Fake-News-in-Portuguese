# %%
import seaborn as sns
import pandas as pd
import os

results_path = os.path.join("results", "models_results.csv")

df = pd.read_csv(results_path)
df.head()
# Out:
#   algorithm         dataset                  vectorizer  accuracy  precision  \
# 0  AdaBoost   pre_processed             CountVectorizer    0.9444     0.9448
# 1  AdaBoost   pre_processed         TfidfVectorizer_idf    0.9403     0.9435
# 2  AdaBoost   pre_processed  TfidfVectorizer_normalized    0.9398     0.9443
# 3  AdaBoost  pre_normalized  TfidfVectorizer_normalized    0.8398     0.8270
# 4  AdaBoost  pre_normalized             CountVectorizer    0.8366     0.8449
#
#    recall      f1  validation_accuracy  train_time  predict_time
# 0  0.9448  0.9448               0.5833      671.54         22.74
# 1  0.9374  0.9405               0.5000      427.41         18.12
# 2  0.9356  0.9399               0.6667      431.03         18.11
# 3  0.8620  0.8441               0.7500      211.98         10.91
# 4  0.8270  0.8359               0.8333      209.87         10.83

# %%
print("Best Acurracys :")
df.sort_values(by=["accuracy"], ascending=[False]).head(10)
# Out:
# Best Acurracys :
#                    algorithm        dataset                  vectorizer  \
# 72                       SVC  pre_processed  TfidfVectorizer_normalized
# 12                  CatBoost  pre_processed             CountVectorizer
# 73                       SVC  pre_processed         TfidfVectorizer_idf
# 74                       SVC  pre_processed             CountVectorizer
# 14                  CatBoost  pre_processed         TfidfVectorizer_idf
# 13                  CatBoost  pre_processed  TfidfVectorizer_normalized
# 54                      LGBM  pre_processed             CountVectorizer
# 30    Extra_Trees_Classifier  pre_processed  TfidfVectorizer_normalized
# 78                       MLP  pre_processed  TfidfVectorizer_normalized
# 66  Random_Forest_Classifier  pre_processed  TfidfVectorizer_normalized
#
#     accuracy  precision  recall      f1  validation_accuracy  train_time  \
# 72    0.9620     0.9564  0.9687  0.9625               0.5833      979.00
# 12    0.9597     0.9604  0.9595  0.9600               0.5000      429.98
# 73    0.9588     0.9520  0.9669  0.9594               0.5833     1615.46
# 74    0.9583     0.9569  0.9604  0.9587               0.5000      435.41
# 14    0.9569     0.9593  0.9549  0.9571               0.5000      713.18
# 13    0.9569     0.9585  0.9558  0.9572               0.5000      710.60
# 54    0.9565     0.9645  0.9485  0.9564               0.5000        8.20
# 30    0.9542     0.9458  0.9641  0.9549               0.5000      144.45
# 78    0.9537     0.9669  0.9402  0.9534               0.7143      811.87
# 66    0.9532     0.9371  0.9724  0.9544               0.5000       38.16
#
#     predict_time
# 72        760.00
# 12         35.29
# 73       1151.44
# 74        307.20
# 14         37.20
# 13         36.26
# 54          0.77
# 30          0.86
# 78          2.10
# 66          0.70

# %%
print("Best Validation Acurracys :")
df.sort_values(by=["validation_accuracy", "accuracy"], ascending=[False, False]).head(10)
# Out:
# Best Validation Acurracys :
#                    algorithm         dataset                  vectorizer  \
# 35    Extra_Trees_Classifier  pre_normalized             CountVectorizer
# 69  Random_Forest_Classifier  pre_normalized             CountVectorizer
# 81                       MLP  pre_normalized  TfidfVectorizer_normalized
# 82                       MLP  pre_normalized         TfidfVectorizer_idf
# 83                       MLP  pre_normalized             CountVectorizer
# 75                       SVC  pre_normalized  TfidfVectorizer_normalized
# 77                       SVC  pre_normalized             CountVectorizer
# 57                      LGBM  pre_normalized         TfidfVectorizer_idf
# 33    Extra_Trees_Classifier  pre_normalized  TfidfVectorizer_normalized
# 58                      LGBM  pre_normalized             CountVectorizer
#
#     accuracy  precision  recall      f1  validation_accuracy  train_time  \
# 35    0.8801     0.8819  0.8795  0.8807               1.0000      131.57
# 69    0.8792     0.8727  0.8896  0.8811               1.0000       42.76
# 81    0.9088     0.9198  0.8970  0.9082               0.9286      557.87
# 82    0.9042     0.9167  0.8905  0.9034               0.9286      541.90
# 83    0.9028     0.9117  0.8933  0.9024               0.9286      439.78
# 75    0.9037     0.9111  0.8960  0.9035               0.9167     1531.28
# 77    0.9000     0.8999  0.9016  0.9007               0.9167     1299.56
# 57    0.8926     0.8992  0.8859  0.8925               0.9167        4.65
# 33    0.8921     0.8976  0.8868  0.8922               0.9167      131.98
# 58    0.8898     0.8884  0.8933  0.8908               0.9167        3.12
#
#     predict_time
# 35          0.62
# 69          0.54
# 81          0.82
# 82          0.99
# 83          1.18
# 75       1095.53
# 77       1114.37
# 57          0.25
# 33          0.60
# 58          0.58

# %%
print("Best Acurracys for each Model :")

df.loc[df.groupby(["algorithm"])["accuracy"].idxmax()].set_index("algorithm")\
                                                      .sort_values(by=["accuracy"], ascending=[False])
# Out:
# Best Acurracys for each Model :
#                                  dataset                  vectorizer  \
# algorithm
# SVC                        pre_processed  TfidfVectorizer_normalized
# CatBoost                   pre_processed             CountVectorizer
# LGBM                       pre_processed             CountVectorizer
# Extra_Trees_Classifier     pre_processed  TfidfVectorizer_normalized
# MLP                        pre_processed  TfidfVectorizer_normalized
# Random_Forest_Classifier   pre_processed  TfidfVectorizer_normalized
# GradientBoost              pre_processed  TfidfVectorizer_normalized
# AdaBoost                   pre_processed             CountVectorizer
# Bernoulli_NB               pre_processed             CountVectorizer
# Decision_Tree_Classifier   pre_processed             CountVectorizer
# Multinomial_NB            pre_normalized  TfidfVectorizer_normalized
# Extra_Tree_Classifier      pre_processed         TfidfVectorizer_idf
# KNN                       pre_normalized  TfidfVectorizer_normalized
# Gaussain_NB               pre_normalized  TfidfVectorizer_normalized
#
#                           accuracy  precision  recall      f1  \
# algorithm
# SVC                         0.9620     0.9564  0.9687  0.9625
# CatBoost                    0.9597     0.9604  0.9595  0.9600
# LGBM                        0.9565     0.9645  0.9485  0.9564
# Extra_Trees_Classifier      0.9542     0.9458  0.9641  0.9549
# MLP                         0.9537     0.9669  0.9402  0.9534
# Random_Forest_Classifier    0.9532     0.9371  0.9724  0.9544
# GradientBoost               0.9500     0.9545  0.9457  0.9501
# AdaBoost                    0.9444     0.9448  0.9448  0.9448
# Bernoulli_NB                0.9139     0.8660  0.9807  0.9198
# Decision_Tree_Classifier    0.8954     0.8924  0.9006  0.8965
# Multinomial_NB              0.8634     0.8968  0.8234  0.8585
# Extra_Tree_Classifier       0.8051     0.8011  0.8151  0.8080
# KNN                         0.7731     0.8074  0.7213  0.7619
# Gaussain_NB                 0.7190     0.7226  0.7167  0.7196
#
#                           validation_accuracy  train_time  predict_time
# algorithm
# SVC                                    0.5833      979.00        760.00
# CatBoost                               0.5000      429.98         35.29
# LGBM                                   0.5000        8.20          0.77
# Extra_Trees_Classifier                 0.5000      144.45          0.86
# MLP                                    0.7143      811.87          2.10
# Random_Forest_Classifier               0.5000       38.16          0.70
# GradientBoost                          0.5000     1780.33          0.60
# AdaBoost                               0.5833      671.54         22.74
# Bernoulli_NB                           0.5000       10.92          1.63
# Decision_Tree_Classifier               0.7500       62.90          0.56
# Multinomial_NB                         0.9167        0.85          0.30
# Extra_Tree_Classifier                  0.4167        2.74          0.52
# KNN                                    0.8333        0.67          8.20
# Gaussain_NB                            0.5833        3.39          1.97

# %% [markdown]
# From here we can see that the majority of models prefered the pre_processed dataset

# %%
#Create a list of all the models that benefit from data scaling
models_to_scale = ['KNN', 'SVC', 'Bernoulli_NB', 'Multinomial_NB', 'Gaussain_NB']

#Create a list of all the models that DOESNT benefit from data scaling
models_without_scale = ['AdaBoost', 'CatBoost', 'Decision_Tree_Classifier', 'Extra_Tree_Classifier', 'Extra_Trees_Classifier', 'GradientBoost', 'LGBM', 'Random_Forest_Classifier']

# %%
df.loc[df["algorithm"].isin(models_to_scale)].groupby(["algorithm", "vectorizer"], as_index = True)\
                                             .mean(numeric_only = True)\
                                             .sort_values(by=["algorithm","accuracy"], ascending=[True, False])\
                                             [["accuracy", "train_time", "predict_time"]]
# Out:
#                                            accuracy  train_time  predict_time
# algorithm      vectorizer
# Bernoulli_NB   CountVectorizer              0.89470       8.505         1.265
#                TfidfVectorizer_idf          0.89470       2.610         1.175
#                TfidfVectorizer_normalized   0.89470       2.645         1.250
# Gaussain_NB    TfidfVectorizer_normalized   0.66855       4.935         2.825
#                CountVectorizer              0.66785       6.690         2.695
#                TfidfVectorizer_idf          0.65765       5.180         2.880
# KNN            TfidfVectorizer_idf          0.72015       0.935        10.900
#                TfidfVectorizer_normalized   0.71895       0.880        11.045
#                CountVectorizer              0.62385       0.105        16.245
# Multinomial_NB CountVectorizer              0.83870       7.040         0.605
#                TfidfVectorizer_idf          0.73010       1.100         0.380
#                TfidfVectorizer_normalized   0.71320       1.090         0.465
# SVC            TfidfVectorizer_normalized   0.93285    1255.140       927.765
#                TfidfVectorizer_idf          0.93080    1644.405      1221.875
#                CountVectorizer              0.92915     867.485       710.785

# %%
df.loc[df["algorithm"].isin(models_without_scale)].groupby(["algorithm", "vectorizer"], as_index = True)\
                                                  .mean(numeric_only = True)\
                                                  .sort_values(by=["algorithm","accuracy"], ascending=[True, False])\
                                                  [["accuracy", "train_time", "predict_time"]]
# Out:
#                                                      accuracy  train_time  \
# algorithm                vectorizer
# AdaBoost                 CountVectorizer              0.89050     440.705
#                          TfidfVectorizer_normalized   0.88980     321.505
#                          TfidfVectorizer_idf          0.88680     320.325
# CatBoost                 CountVectorizer              0.92405     316.710
#                          TfidfVectorizer_normalized   0.92175     520.100
#                          TfidfVectorizer_idf          0.92080     526.640
# Decision_Tree_Classifier CountVectorizer              0.83335      49.520
#                          TfidfVectorizer_idf          0.82500      45.950
#                          TfidfVectorizer_normalized   0.81900      48.155
# Extra_Tree_Classifier    TfidfVectorizer_idf          0.74100       2.365
#                          CountVectorizer              0.73750       2.520
#                          TfidfVectorizer_normalized   0.72410       2.570
# Extra_Trees_Classifier   TfidfVectorizer_normalized   0.92315     138.215
#                          TfidfVectorizer_idf          0.92035     137.400
#                          CountVectorizer              0.91600     149.410
# GradientBoost            TfidfVectorizer_normalized   0.90000    1360.310
#                          CountVectorizer              0.89930    1847.475
#                          TfidfVectorizer_idf          0.89725    1357.410
# LGBM                     CountVectorizer              0.92315       5.660
#                          TfidfVectorizer_idf          0.92200       9.170
#                          TfidfVectorizer_normalized   0.91920       9.090
# Random_Forest_Classifier CountVectorizer              0.91415      43.325
#                          TfidfVectorizer_idf          0.91250      40.305
#                          TfidfVectorizer_normalized   0.91110      41.115
#
#                                                      predict_time
# algorithm                vectorizer
# AdaBoost                 CountVectorizer                   16.785
#                          TfidfVectorizer_normalized        14.510
#                          TfidfVectorizer_idf               14.540
# CatBoost                 CountVectorizer                   27.875
#                          TfidfVectorizer_normalized        28.430
#                          TfidfVectorizer_idf               29.500
# Decision_Tree_Classifier CountVectorizer                    0.445
#                          TfidfVectorizer_idf                0.415
#                          TfidfVectorizer_normalized         0.520
# Extra_Tree_Classifier    TfidfVectorizer_idf                0.430
#                          CountVectorizer                    0.445
#                          TfidfVectorizer_normalized         0.515
# Extra_Trees_Classifier   TfidfVectorizer_normalized         0.730
#                          TfidfVectorizer_idf                0.690
#                          CountVectorizer                    0.800
# GradientBoost            TfidfVectorizer_normalized         0.495
#                          CountVectorizer                    0.565
#                          TfidfVectorizer_idf                0.515
# LGBM                     CountVectorizer                    0.675
#                          TfidfVectorizer_idf                0.255
#                          TfidfVectorizer_normalized         0.265
# Random_Forest_Classifier CountVectorizer                    0.630
#                          TfidfVectorizer_idf                0.600
#                          TfidfVectorizer_normalized         0.620

# %%
df.loc[df["algorithm"] == "Decision_Tree_Classifier"]
# Out:
#                    algorithm         dataset                  vectorizer  \
# 18  Decision_Tree_Classifier   pre_processed             CountVectorizer
# 19  Decision_Tree_Classifier   pre_processed  TfidfVectorizer_normalized
# 20  Decision_Tree_Classifier   pre_processed         TfidfVectorizer_idf
# 21  Decision_Tree_Classifier  pre_normalized             CountVectorizer
# 22  Decision_Tree_Classifier  pre_normalized         TfidfVectorizer_idf
# 23  Decision_Tree_Classifier  pre_normalized  TfidfVectorizer_normalized
#
#     accuracy  precision  recall      f1  validation_accuracy  train_time  \
# 18    0.8954     0.8924  0.9006  0.8965               0.7500       62.90
# 19    0.8889     0.9029  0.8730  0.8877               0.6667       57.38
# 20    0.8833     0.8935  0.8721  0.8827               0.6667       55.90
# 21    0.7713     0.7768  0.7654  0.7711               0.7500       36.14
# 22    0.7667     0.7697  0.7654  0.7675               0.6667       36.00
# 23    0.7491     0.7544  0.7433  0.7488               0.7500       38.93
#
#     predict_time
# 18          0.56
# 19          0.70
# 20          0.52
# 21          0.33
# 22          0.31
# 23          0.34
