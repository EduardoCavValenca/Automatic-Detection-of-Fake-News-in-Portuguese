# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import importlib
import sys
sys.path.append("visualization_files/")
import results_graphs
importlib.reload(results_graphs)
# Out:
# <module 'results_graphs' from 'd:\\Projetos\\TCC\\visualization_files\\results_graphs.py'>

# %%
#Compare best models with feature limit

df_path = os.path.join('results', 'models_results.csv')
df = pd.read_csv(df_path)
df
# Out:
#                     algorithm         dataset                vectorizer  \
# 0                    AdaBoost  pre_normalized   TfidfVectorizer_idf_256
# 1                    AdaBoost  pre_normalized       CountVectorizer_256
# 2                    AdaBoost  pre_normalized  TfidfVectorizer_norm_256
# 3                    AdaBoost  pre_normalized  TfidfVectorizer_norm_max
# 4                    AdaBoost  pre_normalized      CountVectorizer_4096
# ..                        ...             ...                       ...
# 331  Random_Forest_Classifier   pre_processed   TfidfVectorizer_idf_max
# 332  Random_Forest_Classifier   pre_processed       CountVectorizer_max
# 333                       SVC   pre_processed  TfidfVectorizer_norm_max
# 334                       SVC   pre_processed   TfidfVectorizer_idf_max
# 335                       SVC   pre_processed       CountVectorizer_max
#
#      accuracy  precision  recall      f1  custom_accuracy  covid_accuracy  \
# 0      0.8468     0.8393  0.8602  0.8496           0.8571          0.7333
# 1      0.8407     0.8449  0.8372  0.8410           0.9286          0.5667
# 2      0.8407     0.8285  0.8620  0.8449           0.7857          0.7333
# 3      0.8398     0.8270  0.8620  0.8441           0.7857          0.6000
# 4      0.8389     0.8469  0.8298  0.8383           0.8571          0.5333
# ..        ...        ...     ...     ...              ...             ...
# 331    0.9514     0.9337  0.9724  0.9527           0.5000          0.5000
# 332    0.9463     0.9263  0.9706  0.9479           0.5714          0.5000
# 333    0.9602     0.9571  0.9641  0.9606           0.5714          0.5333
# 334    0.9602     0.9554  0.9660  0.9607           0.5714          0.5333
# 335    0.9579     0.9560  0.9604  0.9582           0.5714          0.5000
#
#      train_time  predict_time
# 0          2.09          0.10
# 1          1.43          0.10
# 2          1.80          0.10
# 3        230.95         11.48
# 4         20.69          1.16
# ..          ...           ...
# 331       35.73          0.66
# 332       42.98          0.70
# 333      923.85        742.23
# 334     1591.13       1146.91
# 335      394.49        258.14
#
# [336 rows x 11 columns]

# %%
df.loc[(df['algorithm'] == 'MLP') & (df["vectorizer"].str.endswith('_max'))]
# Out:
#     algorithm         dataset                vectorizer  accuracy  precision  \
# 157       MLP  pre_normalized  TfidfVectorizer_norm_max    0.9111     0.9242
# 160       MLP  pre_normalized   TfidfVectorizer_idf_max    0.9042     0.9167
# 162       MLP  pre_normalized       CountVectorizer_max    0.9005     0.9052
# 324       MLP   pre_processed  TfidfVectorizer_norm_max    0.9551     0.9705
# 325       MLP   pre_processed   TfidfVectorizer_idf_max    0.9477     0.9656
# 326       MLP   pre_processed       CountVectorizer_max    0.9213     0.8856
#
#      recall      f1  custom_accuracy  covid_accuracy  train_time  predict_time
# 157  0.8970  0.9104           0.9286          0.8333      397.70          0.56
# 160  0.8905  0.9034           0.9286          0.8333      362.82          0.49
# 162  0.8960  0.9006           0.9286          0.8000      238.49          0.71
# 324  0.9393  0.9547           0.6429          0.8000      581.04          0.76
# 325  0.9292  0.9470           0.6429          0.8333      527.31          0.77
# 326  0.9687  0.9253           0.5714          0.7000      302.90          1.15

# %%
df_plot = df.groupby("dataset", as_index=True).mean(numeric_only = True)[["accuracy","custom_accuracy","covid_accuracy"]]
graph_compare_datasets_accuracy(df_plot, "Accuracy by dataset")
df_plot
# Out:
#                 accuracy  custom_accuracy  covid_accuracy
# dataset
# pre_normalized  0.839783         0.854176        0.694043
# pre_processed   0.900616         0.595236        0.557736

# %%
df = df.loc[df["dataset"]=="pre_normalized"]

df.groupby("algorithm", as_index=True)\
            .mean(numeric_only = True)\
            [["accuracy","custom_accuracy","covid_accuracy","train_time"]]\
            .sort_values(by=["custom_accuracy","covid_accuracy","accuracy"], ascending=[False,False,False])
# Out:
#                           accuracy  custom_accuracy  covid_accuracy  \
# algorithm
# Random_Forest_Classifier  0.869567         0.952400        0.727775
# Extra_Trees_Classifier    0.882992         0.940492        0.755558
# Bernoulli_NB              0.867925         0.928600        0.808325
# GradientBoost             0.846517         0.928600        0.744450
# CatBoost                  0.885658         0.916683        0.738883
# SVC                       0.901383         0.916683        0.702775
# LGBM                      0.887150         0.910725        0.647217
# Multinomial_NB            0.866292         0.863100        0.788867
# AdaBoost                  0.837225         0.827367        0.652775
# MLP                       0.896267         0.821442        0.716658
# Decision_Tree_Classifier  0.767700         0.761900        0.611108
# Gaussain_NB               0.805358         0.755950        0.716667
# Extra_Tree_Classifier     0.712458         0.726192        0.563875
# KNN                       0.730467         0.708325        0.541667
#
#                           train_time
# algorithm
# Random_Forest_Classifier   15.405000
# Extra_Trees_Classifier     45.645833
# Bernoulli_NB                0.988333
# GradientBoost             288.134167
# CatBoost                  118.423333
# SVC                       397.496667
# LGBM                        2.010000
# Multinomial_NB              0.657500
# AdaBoost                   65.314167
# MLP                       102.470833
# Decision_Tree_Classifier   12.100833
# Gaussain_NB                 1.090000
# Extra_Tree_Classifier       0.635000
# KNN                         0.140833

# %%
selected_models = ["Bernoulli_NB","Random_Forest_Classifier", "SVC", "MLP"]

df_selected = df.loc[df["algorithm"].isin(selected_models)]

# %%
print("Setup of the models with best accuracy")
df_selected.loc[df_selected.groupby(["algorithm"])["accuracy"].idxmax()].set_index("algorithm")\
                                                      .sort_values(by=["accuracy"], ascending=[False])
# Out:
# Setup of the models with best accuracy
#                                  dataset                vectorizer  accuracy  \
# algorithm
# SVC                       pre_normalized  TfidfVectorizer_idf_4096    0.9157
# MLP                       pre_normalized  TfidfVectorizer_idf_4096    0.9144
# Bernoulli_NB              pre_normalized      CountVectorizer_4096    0.8856
# Random_Forest_Classifier  pre_normalized   TfidfVectorizer_idf_max    0.8815
#
#                           precision  recall      f1  custom_accuracy  \
# algorithm
# SVC                          0.9233  0.9080  0.9156           0.8571
# MLP                          0.9263  0.9016  0.9138           0.7143
# Bernoulli_NB                 0.8889  0.8832  0.8860           0.9286
# Random_Forest_Classifier     0.8774  0.8887  0.8830           1.0000
#
#                           covid_accuracy  train_time  predict_time
# algorithm
# SVC                               0.7667       55.18         63.95
# MLP                               0.7667       47.86          0.04
# Bernoulli_NB                      0.7667        0.55          0.09
# Random_Forest_Classifier          0.8333       46.05          0.57

# %%
print("Setup of the models with best custom_accuracy")
df_selected.loc[df_selected.groupby(["algorithm"])["custom_accuracy"].idxmax()].set_index("algorithm")\
                                                      .sort_values(by=["custom_accuracy"], ascending=[False])
# Out:
# Setup of the models with best custom_accuracy
#                                  dataset                vectorizer  accuracy  \
# algorithm
# Random_Forest_Classifier  pre_normalized   TfidfVectorizer_idf_max    0.8815
# Bernoulli_NB              pre_normalized      CountVectorizer_4096    0.8856
# MLP                       pre_normalized  TfidfVectorizer_norm_max    0.9111
# SVC                       pre_normalized  TfidfVectorizer_idf_1024    0.9134
#
#                           precision  recall      f1  custom_accuracy  \
# algorithm
# Random_Forest_Classifier     0.8774  0.8887  0.8830           1.0000
# Bernoulli_NB                 0.8889  0.8832  0.8860           0.9286
# MLP                          0.9242  0.8970  0.9104           0.9286
# SVC                          0.9253  0.9006  0.9128           0.9286
#
#                           covid_accuracy  train_time  predict_time
# algorithm
# Random_Forest_Classifier          0.8333       46.05          0.57
# Bernoulli_NB                      0.7667        0.55          0.09
# MLP                               0.8333      397.70          0.56
# SVC                               0.7000       10.54          6.43

# %%
print("Setup of the models with best covid_accuracy")
df_selected.loc[df_selected.groupby(["algorithm"])["covid_accuracy"].idxmax()].set_index("algorithm")\
                                                      .sort_values(by=["covid_accuracy"], ascending=[False])
# Out:
# Setup of the models with best covid_accuracy
#                                  dataset                 vectorizer  accuracy  \
# algorithm
# Random_Forest_Classifier  pre_normalized  TfidfVectorizer_norm_4096    0.8769
# Bernoulli_NB              pre_normalized        CountVectorizer_max    0.8755
# MLP                       pre_normalized   TfidfVectorizer_norm_max    0.9111
# SVC                       pre_normalized    TfidfVectorizer_idf_max    0.9028
#
#                           precision  recall      f1  custom_accuracy  \
# algorithm
# Random_Forest_Classifier     0.8735  0.8832  0.8783           0.9286
# Bernoulli_NB                 0.8956  0.8519  0.8732           0.9286
# MLP                          0.9242  0.8970  0.9104           0.9286
# SVC                          0.9102  0.8951  0.9026           0.8571
#
#                           covid_accuracy  train_time  predict_time
# algorithm
# Random_Forest_Classifier          0.8667        9.86          0.11
# Bernoulli_NB                      0.8333        6.28          0.99
# MLP                               0.8333      397.70          0.56
# SVC                               0.8000     1699.25       1169.01

# %%
df_plot = df_selected.groupby(df_selected["vectorizer"].str.split('_').str[-1])\
            .mean(numeric_only=True)\
            .sort_values(by=["train_time"], ascending=[True])

df_plot_graph = df_plot[["accuracy","custom_accuracy","covid_accuracy"]]
results_graphs.graph_compare_feature_num_accuracys(df_plot_graph, title = "Comparing filtered vocabulary sizes")
df_plot
# Out:
#             accuracy  precision    recall        f1  custom_accuracy  \
# vectorizer
# 256         0.869983   0.868533  0.875258  0.871558         0.928592
# 1024        0.880742   0.885708  0.876625  0.881033         0.880975
# 4096        0.895008   0.898625  0.892383  0.895425         0.880967
# max         0.889408   0.897992  0.880408  0.889000         0.928592
#
#             covid_accuracy  train_time  predict_time
# vectorizer
# 256               0.672225    4.146667      0.371667
# 1024              0.680542    8.955000      1.587500
# 4096              0.786117   24.785000     15.435000
# max               0.816650  478.474167    241.387500

# %%
df_plot = pd.concat([df_selected.loc[df_selected["vectorizer"].str.startswith('CountVectorizer')].mean(numeric_only=True).to_frame().T,
           df_selected.loc[df_selected["vectorizer"].str.startswith('TfidfVectorizer_norm')].mean(numeric_only=True).to_frame().T,
           df_selected.loc[df_selected["vectorizer"].str.startswith('TfidfVectorizer_idf')].mean(numeric_only=True).to_frame().T])\
           .set_axis(['CountVectorizer', 'TfidfVectorizer_norm', 'TfidfVectorizer_idf'], axis=0)

df_plot.index.name = "vectorizer"
df_plot_graph = df_plot[["accuracy","custom_accuracy","covid_accuracy"]]

results_graphs.graph_compare_feature_num_accuracys(df_plot_graph, title = "Comparing vectorizers types ")
df_plot
# Out:
#                       accuracy  precision    recall        f1  \
# vectorizer
# CountVectorizer       0.883394   0.886375  0.881894  0.883962
# TfidfVectorizer_norm  0.883962   0.888294  0.880869  0.884387
# TfidfVectorizer_idf   0.884000   0.888475  0.880744  0.884413
#
#                       custom_accuracy  covid_accuracy  train_time  \
# vectorizer
# CountVectorizer              0.915194        0.729156  109.463750
# TfidfVectorizer_norm         0.901812        0.741663  135.111250
# TfidfVectorizer_idf          0.897338        0.745831  142.695625
#
#                       predict_time
# vectorizer
# CountVectorizer           55.30250
# TfidfVectorizer_norm      61.08500
# TfidfVectorizer_idf       77.69875

# %%
fig, axes = plt.subplots(2, 2, figsize=(11, 6))
axes = axes.ravel()

for i, model in enumerate(selected_models):
    df_plot = df_selected.loc[df_selected["algorithm"]==model]
    df_plot = df_plot.groupby(df_selected["vectorizer"].str.split('_').str[-1])\
                     .mean(numeric_only=True)\
                     .sort_values(by=["train_time"], ascending=[True])

    df_plot = df_plot[["accuracy","custom_accuracy","covid_accuracy"]]
    results_graphs.graph_compare_feature_num_accuracys(df_plot, title = model, ax=axes[i])
plt.tight_layout()

# %%
df_plot = df_selected.groupby(df_selected["vectorizer"].str.split('_').str[-1])\
            .mean(numeric_only=True)\
            .sort_values(by=["train_time"], ascending=[True])

df_plot_graph = df_plot[["train_time"]]
results_graphs.graph_compare_feature_num_train(df_plot_graph, title = "Comparing training time for vocabulary sizes")
df_plot
# Out:
#             accuracy  precision    recall        f1  custom_accuracy  \
# vectorizer
# 256         0.869983   0.868533  0.875258  0.871558         0.928592
# 1024        0.880742   0.885708  0.876625  0.881033         0.880975
# 4096        0.895008   0.898625  0.892383  0.895425         0.880967
# max         0.889408   0.897992  0.880408  0.889000         0.928592
#
#             covid_accuracy  train_time  predict_time
# vectorizer
# 256               0.672225    4.146667      0.371667
# 1024              0.680542    8.955000      1.587500
# 4096              0.786117   24.785000     15.435000
# max               0.816650  478.474167    241.387500
