# %%
import networkx as nx
from tqdm.notebook import tqdm
import os
import statistics
import pandas as pd

import sys
sys.path.append( '.' )
import importlib

import measures
importlib.reload(measures)
# Out:
# <module 'measures' from 'd:\\Projetos\\TCC\\Part_2.1-Complex_Networks\\syntactic\\measures.py'>

# %%
def add_row_to_df(df, i, label, measures, news_id):
    
    df.loc[i, 'news_id'] = news_id
    df.loc[i, 'betweenness'] = measures['betweenness']
    df.loc[i, 'closeness'] = measures['closeness']
    df.loc[i, 'eigenvector'] = measures['eigenvector']
    df.loc[i, 'katz'] = measures['katz']
    df.loc[i, 'pagerank'] = measures['pagerank']
    df.loc[i, 'hubs'] = measures['hubs']
    df.loc[i, 'authorities'] = measures['authorities']

    df.loc[i, 'clustering'] = measures['clustering']
    df.loc[i, 'average_clustering'] = measures['average_clustering']
    df.loc[i, 'correlation'] = measures['correlation']
    df.loc[i, 'transitivity'] = measures['transitivity']

    df.loc[i, 'density'] = measures['density']
    
    df.loc[i, 'label'] = label

    return df

# %%
df = pd.DataFrame(columns=['news_id', 'betweenness', 'closeness', 'eigenvector', 'katz', 'pagerank', 'hubs', 'authorities', 
                           'clustering', 'average_clustering', 'correlation', 'transitivity','density', 'label'])

i = 0
for file in tqdm(os.listdir('data/udpipe_tuples/' + 'fake')):

    fake_file_path = 'data/udpipe_tuples/' + 'fake' + '/' + file
    true_file_path = 'data/udpipe_tuples/' + 'true' + '/' + file

    G_fake = measures.generate_graph_udpipe_word(fake_file_path)
    G_true = measures.generate_graph_udpipe_word(true_file_path)

    measures_fake = measures.get_measures_from_graph_word(G_fake)
    measures_true = measures.get_measures_from_graph_word(G_true)

    for key, value in list(measures_fake.items()):
        if  isinstance(value, dict):
            measures_fake[key] = statistics.mean(value.values())

    for key, value in list(measures_true.items()):
        if  isinstance(value, dict):
            measures_true[key] = statistics.mean(value.values())
    
    news_id = file.split('.')[0]

    add_row_to_df(df, i, "fake", measures_fake, news_id)
    add_row_to_df(df, i+1, "true", measures_true, news_id)

    i += 2

# %%
df
# Out:
#      news_id  betweenness  closeness  eigenvector      katz  pagerank  \
# 0          1     0.004944   0.042442     0.090120  0.126569  0.016129
# 1          1     0.002717   0.023223     0.038462  0.113139  0.012821
# 2         10     0.003582   0.023622     0.078249  0.091929  0.008475
# 3         10     0.006670   0.033007     0.064814  0.089205  0.008000
# 4        100     0.001567   0.025094     0.017914  0.089885  0.008130
# ...      ...          ...        ...          ...       ...       ...
# 7195     997     0.002567   0.023944     0.058132  0.089592  0.008065
# 7196     998     0.005468   0.040138     0.107072  0.138595  0.019231
# 7197     998     0.003209   0.030073     0.021345  0.130134  0.016949
# 7198     999     0.004001   0.028176     0.045937  0.078322  0.006173
# 7199     999     0.001189   0.016754     0.058876  0.075195  0.005682
#
#           hubs  authorities  clustering  average_clustering  correlation  \
# 0     0.016129     0.016129    0.009725            0.009725     0.038034
# 1     0.012821     0.012821    0.002564            0.002564     0.141270
# 2     0.008475     0.008475    0.001530            0.001530    -0.039233
# 3     0.008000     0.008000    0.008095            0.008095     0.047405
# 4     0.008130     0.008130    0.000000            0.000000    -0.139617
# ...        ...          ...         ...                 ...          ...
# 7195  0.008065     0.008065    0.004464            0.004464     0.044648
# 7196  0.019231     0.019231    0.000000            0.000000     0.293378
# 7197  0.016949     0.016949    0.000000            0.000000     0.317239
# 7198  0.006173     0.006173    0.014278            0.014278    -0.057224
# 7199  0.005682     0.005682    0.014931            0.014931     0.064399
#
#       transitivity   density label
# 0         0.025773  0.019566  fake
# 1         0.007353  0.013986  true
# 2         0.002358  0.010068  fake
# 3         0.007837  0.009613  true
# 4         0.000000  0.009929  fake
# ...            ...       ...   ...
# 7195      0.005208  0.010031  true
# 7196      0.000000  0.021116  fake
# 7197      0.000000  0.018118  true
# 7198      0.010870  0.008320  fake
# 7199      0.010386  0.007110  true
#
# [7200 rows x 14 columns]

# %%
df = df.fillna(df["correlation"].mean())
df
# Out:
#      news_id  betweenness  closeness  eigenvector      katz  pagerank  \
# 0          1     0.004944   0.042442     0.090120  0.126569  0.016129
# 1          1     0.002717   0.023223     0.038462  0.113139  0.012821
# 2         10     0.003582   0.023622     0.078249  0.091929  0.008475
# 3         10     0.006670   0.033007     0.064814  0.089205  0.008000
# 4        100     0.001567   0.025094     0.017914  0.089885  0.008130
# ...      ...          ...        ...          ...       ...       ...
# 7195     997     0.002567   0.023944     0.058132  0.089592  0.008065
# 7196     998     0.005468   0.040138     0.107072  0.138595  0.019231
# 7197     998     0.003209   0.030073     0.021345  0.130134  0.016949
# 7198     999     0.004001   0.028176     0.045937  0.078322  0.006173
# 7199     999     0.001189   0.016754     0.058876  0.075195  0.005682
#
#           hubs  authorities  clustering  average_clustering  correlation  \
# 0     0.016129     0.016129    0.009725            0.009725     0.038034
# 1     0.012821     0.012821    0.002564            0.002564     0.141270
# 2     0.008475     0.008475    0.001530            0.001530    -0.039233
# 3     0.008000     0.008000    0.008095            0.008095     0.047405
# 4     0.008130     0.008130    0.000000            0.000000    -0.139617
# ...        ...          ...         ...                 ...          ...
# 7195  0.008065     0.008065    0.004464            0.004464     0.044648
# 7196  0.019231     0.019231    0.000000            0.000000     0.293378
# 7197  0.016949     0.016949    0.000000            0.000000     0.317239
# 7198  0.006173     0.006173    0.014278            0.014278    -0.057224
# 7199  0.005682     0.005682    0.014931            0.014931     0.064399
#
#       transitivity   density label
# 0         0.025773  0.019566  fake
# 1         0.007353  0.013986  true
# 2         0.002358  0.010068  fake
# 3         0.007837  0.009613  true
# 4         0.000000  0.009929  fake
# ...            ...       ...   ...
# 7195      0.005208  0.010031  true
# 7196      0.000000  0.021116  fake
# 7197      0.000000  0.018118  true
# 7198      0.010870  0.008320  fake
# 7199      0.010386  0.007110  true
#
# [7200 rows x 14 columns]

# %%
df.to_csv('../csvs/syntatic_word_mean_measures.csv', index=False)
