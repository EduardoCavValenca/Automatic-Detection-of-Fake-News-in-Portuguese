# %%
import networkx as nx
from tqdm.notebook import tqdm
import os
import statistics
import pandas as pd

import sys
sys.path.append( '.' )
import importlib

import measures
importlib.reload(measures)
# Out:
# <module 'measures' from 'd:\\Projetos\\TCC\\Part_2.1-Complex_Networks\\syntactic\\measures.py'>

# %%
def add_row_to_df(df, i, label, measures, news_id):
    
    df.loc[i, 'news_id'] = news_id
    df.loc[i, 'betweenness'] = measures['betweenness']
    df.loc[i, 'closeness'] = measures['closeness']
    df.loc[i, 'eigenvector'] = measures['eigenvector']
    df.loc[i, 'katz'] = measures['katz']
    df.loc[i, 'pagerank'] = measures['pagerank']
    df.loc[i, 'hubs'] = measures['hubs']
    df.loc[i, 'authorities'] = measures['authorities']

    df.loc[i, 'clustering'] = measures['clustering']
    df.loc[i, 'average_clustering'] = measures['average_clustering']
    df.loc[i, 'correlation'] = measures['correlation']
    df.loc[i, 'transitivity'] = measures['transitivity']

    df.loc[i, 'density'] = measures['density']
    
    df.loc[i, 'label'] = label

    return df

# %%
df = pd.DataFrame(columns=['news_id', 'betweenness', 'closeness', 'eigenvector', 'katz', 'pagerank', 'hubs', 'authorities', 
                           'clustering', 'average_clustering', 'correlation', 'transitivity','density', 'label'])

i = 0
for file in tqdm(os.listdir('data/udpipe_tuples_with_stopwords/' + 'fake')):

    fake_file_path = 'data/udpipe_tuples_with_stopwords/' + 'fake' + '/' + file
    true_file_path = 'data/udpipe_tuples_with_stopwords/' + 'true' + '/' + file

    G_fake = measures.generate_graph_udpipe_word(fake_file_path)
    G_true = measures.generate_graph_udpipe_word(true_file_path)

    measures_fake = measures.get_measures_from_graph_word(G_fake)
    measures_true = measures.get_measures_from_graph_word(G_true)

    for key, value in list(measures_fake.items()):
        if  isinstance(value, dict):
            measures_fake[key] = max(value.values())

    for key, value in list(measures_true.items()):
        if  isinstance(value, dict):
            measures_true[key] = max(value.values())
    
    news_id = file.split('.')[0]

    add_row_to_df(df, i, "fake", measures_fake, news_id)
    add_row_to_df(df, i+1, "true", measures_true, news_id)

    i += 2

# %%
df
# Out:
#      news_id  betweenness  closeness  eigenvector      katz  pagerank  \
# 0          1     0.025263   0.160788     0.441726  0.189217  0.043937
# 1          1     0.010625   0.201801     0.724654  0.214271  0.058076
# 2         10     0.012975   0.201985     0.516411  0.232832  0.057958
# 3         10     0.025470   0.145971     0.476854  0.205151  0.039107
# 4        100     0.076653   0.235822     0.490916  0.254407  0.048346
# ...      ...          ...        ...          ...       ...       ...
# 7195     997     0.028652   0.243916     0.642703  0.270131  0.055594
# 7196     998     0.025114   0.156556     0.586538  0.198373  0.054275
# 7197     998     0.023629   0.230907     0.694723  0.252205  0.083260
# 7198     999     0.016781   0.133819     0.365121  0.161471  0.032105
# 7199     999     0.012901   0.174739     0.599708  0.199278  0.051696
#
#           hubs  authorities  clustering  average_clustering  correlation  \
# 0     0.102104     0.081168    0.500000            0.021084    -0.238608
# 1     0.049378     0.196722    0.166667            0.009144    -0.277525
# 2     0.048296     0.297281    0.333333            0.011587    -0.223655
# 3     0.046416     0.168164    0.500000            0.008857    -0.195886
# 4     0.034031     0.172979    0.166667            0.017031    -0.155208
# ...        ...          ...         ...                 ...          ...
# 7195  0.033996     0.190338    0.500000            0.029104    -0.167807
# 7196  0.096739     0.276239    0.166667            0.005336    -0.228939
# 7197  0.081391     0.325249    0.500000            0.017666    -0.161410
# 7198  0.038133     0.068371    0.333333            0.016806    -0.222145
# 7199  0.033744     0.129287    0.333333            0.015333    -0.215416
#
#       transitivity   density label
# 0         0.015873  0.017064  fake
# 1         0.011834  0.015976  true
# 2         0.016129  0.011082  fake
# 3         0.010127  0.011110  true
# 4         0.027778  0.012298  fake
# ...            ...       ...   ...
# 7195      0.041162  0.012617  true
# 7196      0.009434  0.019807  fake
# 7197      0.020833  0.018210  true
# 7198      0.015670  0.010256  fake
# 7199      0.019737  0.008525  true
#
# [7200 rows x 14 columns]

# %%
df = df.fillna(df["correlation"].mean())
df
# Out:
#      news_id  betweenness  closeness  eigenvector      katz  pagerank  \
# 0          1     0.025263   0.160788     0.441726  0.189217  0.043937
# 1          1     0.010625   0.201801     0.724654  0.214271  0.058076
# 2         10     0.012975   0.201985     0.516411  0.232832  0.057958
# 3         10     0.025470   0.145971     0.476854  0.205151  0.039107
# 4        100     0.076653   0.235822     0.490916  0.254407  0.048346
# ...      ...          ...        ...          ...       ...       ...
# 7195     997     0.028652   0.243916     0.642703  0.270131  0.055594
# 7196     998     0.025114   0.156556     0.586538  0.198373  0.054275
# 7197     998     0.023629   0.230907     0.694723  0.252205  0.083260
# 7198     999     0.016781   0.133819     0.365121  0.161471  0.032105
# 7199     999     0.012901   0.174739     0.599708  0.199278  0.051696
#
#           hubs  authorities  clustering  average_clustering  correlation  \
# 0     0.102104     0.081168    0.500000            0.021084    -0.238608
# 1     0.049378     0.196722    0.166667            0.009144    -0.277525
# 2     0.048296     0.297281    0.333333            0.011587    -0.223655
# 3     0.046416     0.168164    0.500000            0.008857    -0.195886
# 4     0.034031     0.172979    0.166667            0.017031    -0.155208
# ...        ...          ...         ...                 ...          ...
# 7195  0.033996     0.190338    0.500000            0.029104    -0.167807
# 7196  0.096739     0.276239    0.166667            0.005336    -0.228939
# 7197  0.081391     0.325249    0.500000            0.017666    -0.161410
# 7198  0.038133     0.068371    0.333333            0.016806    -0.222145
# 7199  0.033744     0.129287    0.333333            0.015333    -0.215416
#
#       transitivity   density label
# 0         0.015873  0.017064  fake
# 1         0.011834  0.015976  true
# 2         0.016129  0.011082  fake
# 3         0.010127  0.011110  true
# 4         0.027778  0.012298  fake
# ...            ...       ...   ...
# 7195      0.041162  0.012617  true
# 7196      0.009434  0.019807  fake
# 7197      0.020833  0.018210  true
# 7198      0.015670  0.010256  fake
# 7199      0.019737  0.008525  true
#
# [7200 rows x 14 columns]

# %%
df.to_csv('../csvs/syntatic_word_max_measures_with_stopwords.csv', index=False)
